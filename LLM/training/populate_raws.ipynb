# %%
import os
print(os.getcwd())
# Out:
# /home/tygo/code/ml-experiments/training

# %%
from gutenberg.gutenberg.src.utils import populate_raw_from_mirror, list_duplicates_in_mirror

dups_list = list_duplicates_in_mirror(
    mirror_dir="gutenberg/gutenberg/data/.mirror"
)

populate_raw_from_mirror(
    mirror_dir="gutenberg/gutenberg/data/.mirror",
    raw_dir="gutenberg/gutenberg/data/raw",
    dups_list=dups_list
)
